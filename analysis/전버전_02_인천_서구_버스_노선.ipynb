# %% [markdown]
# ## 구글 드라이브와 연결

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# koreanize-matplotlib 라이브러리 설치
# !pip install koreanize-matplotlib

# matplotlib 라이브러리, matplotlib에서 한글을 사용하기 위한 라이브러리 임포트
import matplotlib.pyplot as plt
import koreanize_matplotlib
# Out:
# Collecting koreanize-matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl.metadata (992 bytes)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from koreanize-matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.17.0)
# Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 46.5 MB/s eta 0:00:00
# Installing collected packages: koreanize-matplotlib
# Successfully installed koreanize-matplotlib-0.1.1

# %%
# 마운트된 드라이브 경로 확인
import os
project_path = '/content/gdrive/My Drive/sw융합프로젝트(1)/'

# 해당 폴더 내 파일 목록 확인
files = os.listdir(project_path)
print(files)
# Out:
# ['행정구역(읍면동)', '행정구역(시군구)', '인천광역시_시내버스 정류소 현황_20241231.csv', '인천광역시.geojson', '아파트(매매)_실거래가_20250512141056.csv', '연립다세대(전월세)_실거래가_20250512142423.csv', '아파트(전월세)_실거래가_20250512142547.csv', '연립다세대(매매)_실거래가_20250512142554.csv', 'apt_geocoded.csv', 'multi_geocoded.csv']

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import folium

# %%
import pandas as pd

# 파일 경로 설정 (Google Drive 또는 로컬 경로에 맞게 수정)
csv_path = '/content/gdrive/My Drive/sw융합프로젝트(1)/인천광역시_시내버스 정류소 현황_20241231.csv'

# 1. CSV 불러오기
df = pd.read_csv(csv_path, encoding='utf-8')  # 한글깨짐 방지
# 위도랑 경도 제대로 고치기
df = df.rename(columns={'위도': '경도_tmp', '경도': '위도'})
df = df.rename(columns={'경도_tmp': '경도'})
df.head()
# Out:
#         기준 일자        정류소 명   정류소 번호     정류소아이디    권역  행정동 명         엑스좌표  \
# 0  2024-12-31  (구)주안2동치안센터  37302.0  163000302  미추홀구   주안2동  170842.1600
# 1  2024-12-31    (주)경동세라믹스  89146.0  168001146    서구  오류왕길동  166087.8384
# 2  2024-12-31     (주)경인양행앞  42096.0  168000096    서구   가좌1동  170343.6370
# 3  2024-12-31     (주)경인양행앞  42097.0  168000097    서구   석남2동  170465.3876
# 4  2024-12-31    (주)대한특수금속  39050.0  165000050   남동구  논현고잔동  172879.0446
#
#            경도         와이좌표         위도
# 0  126.671236  439486.1420  37.457078
# 1  126.616978  450837.1724  37.559186
# 2  126.665414  444145.8737  37.499045
# 3  126.666789  444178.4131  37.499342
# 4  126.694491  433147.5666  37.400029

# %%
# 2. 서구만 필터링
df['권역'] = df['권역'].str.strip()
df = df[df['권역'] == '서구']

df['geometry'] = df.apply(lambda row: Point(row['경도'], row['위도']), axis=1)

gdf_seogu_bus = gpd.GeoDataFrame(df, geometry='geometry', crs='EPSG:4326')

# %%
# 평균 중심 계산
center_lat = gdf_seogu_bus['위도'].mean()  # 실제 위도
center_lon = gdf_seogu_bus['경도'].mean()  # 실제 경도

m = folium.Map(location=[center_lat, center_lon], zoom_start=13)

for _, row in gdf_seogu_bus.iterrows():
    folium.CircleMarker(
        location=[row['위도'], row['경도']],  # 위도, 경도 순서!
        radius=3,
        color='blue',
        fill=True,
        fill_opacity=0.7,
        popup=row['정류소 명']
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a554b147e931cd832faa5e9d68b3402e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a554b147e931cd832faa5e9d68b3402e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a554b147e931cd832faa5e9d68b3402e = L.map(
#                 &quot;map_a554b147e931cd832faa5e9d68b3402e&quot;,
#                 {
#                     center: [37.54771702006451, 126.66106521953917],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4938167995db6c6c5c9c218d530068bd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4938167995db6c6c5c9c218d530068bd.addTo(map_a554b147e931cd832faa5e9d68b3402e);
#
#
#             var circle_marker_ebaa16924b43e82ebb0c878104ae21bf = L.circleMarker(
#                 [37.55918552, 126.6169776],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a554b147e931cd832faa5e9d68b3402e);
#
#
#         var popup_87a8e64b47cd2def592691f4008f3134 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a1232c570b46a7da43cba3ceef56f7e = $(`&lt;div id=&quot;html_1a1232c570b46a7da43cba3ceef56f7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(주)경동세라믹스&lt;/div&gt;`)[0];
#                 popup_87a8e64b47cd2def592691f4008f3134.setContent(html_1a1232c570b46a7da43cba3ceef56f7e);
#
#
#
#         circle_marker_ebaa16924b43e82ebb0c878104ae21bf.bindPopup(popup_87a8e64b47cd2def592691f4008f3134)
#         ;
#
#
#
#
#             var circle_marker_779c75a6a78a562811047512aa93efcf = L.circleMarker(
#                 [37.49904538, 126.6654136],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a554b147e931cd832faa5e9d68b3402e);
#
#
#         var popup_8fef8e4714ff08b2d3161440137c89b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a47c83e63882862eaadc106104dc3e0 = $(`&lt;div id=&quot;html_6a47c83e63882862eaadc106104dc3e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(주)경인양행앞&lt;/div&gt;`)[0];
#                 popup_8fef8e4714ff08b2d3161440137c89b8.setContent(html_6a47c83e63882862eaadc106104dc3e0);
#
#
#
#         circle_marker_779c75a6a78a562811047512aa93efcf.bindPopup(popup_8fef8e4714ff08b2d3161440137c89b8)
#         ;
#
#
#
#
#             var circle_marker_3fc26e6803a4531954ed9d10907879f9 = L.circleMarker(
#                 [37.49934246, 126.6667891],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a554b147e931cd832faa5e9d68b3402e);
#
#
#         var popup_1a4125701484978568a4607078e43164 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9456b3f46259e0525c974c3d659996fc = $(`&lt;div id=&quot;html_9456b3f46259e0525c974c3d659996fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(주)경인양행앞&lt;/div&gt;`)[0];
#                 popup_1a4125701484978568a4607078e43164.setContent(html_9456b3f46259e0525c974c3d659996fc);
#
#
#
#         circle_marker_3fc26e6803a4531954ed9d10907879f9.bindPopup(popup_1a4125701484978568a4607078e43164)
#         ;
#
#
#
#
#             var circle_marker_7b54d98e62b6115de64b90e46e3a55dd = L.circleMarker(
#                 [37.50190268, 126.6174734],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: tr

# %%
import pandas as pd
import geopandas as gpd
import folium
from shapely.geometry import Point

# 3. 위도/경도 형변환 및 결측 제거
df['위도'] = pd.to_numeric(df['위도'], errors='coerce')
df['경도'] = pd.to_numeric(df['경도'], errors='coerce')
df = df.dropna(subset=['위도', '경도'])

# 4. GeoDataFrame 변환 (Point(경도, 위도))
df['geometry'] = df.apply(lambda row: Point(row['경도'], row['위도']), axis=1)
gdf_bus = gpd.GeoDataFrame(df, geometry='geometry', crs='EPSG:4326')

# 5. 행정동별 정류장 수 집계
dong_counts = gdf_bus['행정동 명'].value_counts().reset_index()
dong_counts.columns = ['행정동 명', '정류장 수']
dong_counts
# Out:
#     행정동 명  정류장 수
# 0    청라3동     97
# 1   오류왕길동     95
# 2   검암경서동     91
# 3     아라동     68
# 4     연희동     65
# 5    청라2동     62
# 6   신현원창동     61
# 7    청라1동     49
# 8    가정1동     44
# 9    가좌1동     44
# 10   검단1동     39
# 11    원당동     39
# 12    청라동     37
# 13   석남2동     34
# 14   가좌4동     29
# 15    당하동     29
# 16   가좌3동     24
# 17   가좌2동     22
# 18    원창동     19
# 19    대곡동     18
# 20   석남1동     17
# 21  불로대곡동     15
# 22    마전동     15
# 23   가정3동     13
# 24   석남3동     13
# 25   가정2동     11
# 26    금곡동      5
# 27    검단동      4
# 28    가정동      4
# 29    불로동      4
# 30    심곡동      4
# 31    백석동      3
# 32    가좌동      2
# 33    오류동      2
# 34    검암동      2
# 35    원찬동      1
# 36   송림4동      1
# 37   검단2동      1
# 38   검단3동      1
# 39    경서동      1

# %%
gdf_seogu_bus
# Out:
#            기준 일자        정류소 명   정류소 번호     정류소아이디  권역  행정동 명         엑스좌표  \
# 1     2024-12-31    (주)경동세라믹스  89146.0  168001146  서구  오류왕길동  166087.8384
# 2     2024-12-31     (주)경인양행앞  42096.0  168000096  서구   가좌1동  170343.6370
# 3     2024-12-31     (주)경인양행앞  42097.0  168000097  서구   석남2동  170465.3876
# 8     2024-12-31     (주)스킨이데아  89388.0  168001388  서구    원찬동  166105.6856
# 9     2024-12-31     (주)스킨이데아  89389.0  168001389  서구    원창동  166107.5171
# ...          ...          ...      ...        ...  ..    ...          ...
# 6856  2024-12-31        효성아파트  42168.0  168000168  서구   석남1동  170282.1244
# 6876  2024-12-31       휴먼시아후문  42885.0  168000885  서구   청라2동  168749.6769
# 6891  2024-12-31         희성금속  42018.0  168000018  서구   가좌3동  171276.1861
# 6892  2024-12-31        힐데스하임  42876.0  168000876  서구   청라1동  169240.1662
# 6895  2024-12-31  힐스테이트검단웰카운티  89572.0  168001572  서구    불로동  173297.5807
#
#               경도         와이좌표         위도                    geometry
# 1     126.616978  450837.1724  37.559186  POINT (126.61698 37.55919)
# 2     126.665414  444145.8737  37.499045  POINT (126.66541 37.49905)
# 3     126.666789  444178.4131  37.499342  POINT (126.66679 37.49934)
# 8     126.617473  444479.2189  37.501903   POINT (126.61747 37.5019)
# 9     126.617495  444459.0933  37.501721   POINT (126.6175 37.50172)
# ...          ...          ...        ...                         ...
# 6856  126.664651  445792.3371  37.513878  POINT (126.66465 37.51388)
# 6876  126.647243  447554.8589  37.529707  POINT (126.64724 37.52971)
# 6891  126.676031  442303.9651  37.482480  POINT (126.67603 37.48248)
# 6892  126.652792  447562.8537  37.529796   POINT (126.65279 37.5298)
# 6895  126.698383  456098.4580  37.606826  POINT (126.69838 37.60683)
#
# [1085 rows x 11 columns]

# %%
import geopandas as gpd
import folium
from shapely.geometry import Point

# 1. 행정동 경계 geojson 불러오기
dong_geo_path = '/content/gdrive/My Drive/sw융합프로젝트(1)/인천광역시.geojson'
gdf_dong = gpd.read_file(dong_geo_path)
gdf_dong['sggnm'] = gdf_dong['sggnm'].str.strip()
gdf_dong = gdf_dong[gdf_dong['sggnm'] == '서구']

# 2. 행정동 명 추출 및 병합용 컬럼 생성
gdf_dong['dong_name'] = gdf_dong['adm_nm'].str.extract(r'(\S+동)')

# 3. dong_counts 컬럼명 정리 및 병합
dong_counts.columns = ['dong_name', '정류장 수']
gdf_merge = gdf_dong.merge(dong_counts, on='dong_name', how='left')
gdf_merge['정류장 수'] = gdf_merge['정류장 수'].fillna(0)
gdf_merge['dong_name'] = gdf_merge['dong_name'].astype(str)

# 4. GeoDataFrame 재정의
gdf_merge = gpd.GeoDataFrame(gdf_merge, geometry='geometry', crs=gdf_dong.crs)

# 5. 지도 생성
m = folium.Map(location=[37.545, 126.675], zoom_start=13)

# 6. Choropleth 층 추가
folium.Choropleth(
    geo_data=gdf_merge.__geo_interface__,
    data=gdf_merge,
    columns=['dong_name', '정류장 수'],
    key_on='feature.properties.dong_name',
    fill_color='YlGnBu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='버스 정류장 수'
).add_to(m)

# 7. 툴팁 및 경계선 추가
folium.GeoJson(
    gdf_merge,
    name="행정동 경계",
    tooltip=folium.GeoJsonTooltip(
        fields=["adm_nm", "정류장 수"],
        aliases=["행정동", "정류장 수"],
        localize=True
    ),
    style_function=lambda x: {
        "fillOpacity": 0,
        "color": "gray",
        "weight": 1
    }
).add_to(m)

# 8. 지도 출력
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_915af75a9772d557a347bf00aa4a941b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_915af75a9772d557a347bf00aa4a941b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_915af75a9772d557a347bf00aa4a941b = L.map(
#                 &quot;map_915af75a9772d557a347bf00aa4a941b&quot;,
#                 {
#                     center: [37.545, 126.675],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e553baa89523e7ccb398dacdfd5f08e3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e553baa89523e7ccb398dacdfd5f08e3.addTo(map_915af75a9772d557a347bf00aa4a941b);
#
#
#             var choropleth_075c8ddc7b1e0c11c3be7f8548bb28fd = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_f0212acbbd5fcf9dd86a8dc4d08e9893_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;19&quot;: case &quot;20&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#253494&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;15&quot;: case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41b6c4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;8&quot;: case &quot;13&quot;: case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7fcdbb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;7&quot;: case &quot;12&quot;: case &quot;14&quot;: case &quot;18&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c7e9b4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_f0212acbbd5fcf9dd86a8dc4d08e9893_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f0212acbbd5fcf9dd86a8dc4d08e9893 = L.geoJson(null, {
#                 onEachFeature: geo_json_f0212acbbd5fcf9dd86a8dc4d08e9893_onEachFeature,
#
#                 style: geo_json_f0212acbbd5fcf9dd86a8dc4d08e9893_styler,
#             ...{
# }
#         });
#
#         function geo_json_f0212acbbd5fcf9dd86a8dc4d08e9893_add (data) {
#             geo_json_f0212acbbd5fcf9dd86a8dc4d08e9893
#                 .addData(data);
#         }
#             geo_json_f0212acbbd5fcf9dd86a8dc4d08e9893_add({&quot;bbox&quot;: [126.55571481737333, 37.47334788579891, 126.72512592212895, 37.63957683199508], &quot;features&quot;: [{&quot;bbox&quot;: [126.55571481737333, 37.543833263707086, 126.70344213273648, 37.592707314660196], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[126.56832349585244, 37.57281742128982], [126.56842825375095, 37.57281371620233], [126.56866077274445, 37.5728384482149], [126.56880695830118, 37.57290744330951], [126.5692978800672, 37.573335390934155], [126.56934861972645, 37.573339899215426], [126.56974589095837, 37.57323197301826], [126.57110253396108, 37.572551100540764], [126.57115905891318, 37.57226848784268], [126.57105912329817, 37.572029364089836], [126.57001337189502, 37.57046666880928], [126.56923326368693, 37.570246318684845], [126.56415216793361, 37.57101721388526], [126.56157717160542, 37.57168326528929], [126.56144715387006, 37.5717333258857], [126.56120954416093, 37.57185037971426], [126.55865720859374, 37.57314954348513], [126.55571481737333, 37.57613734370768], [126.55580298984542, 37.57885521381794], [126.55640003981819, 37.578856204474526], [126.55678845783441, 37.5787600939699], [126.55802005687134, 37.577858

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import folium

# 2. 위도/경도 숫자화 및 결측 제거
gdf_seogu_bus['위도'] = pd.to_numeric(gdf_seogu_bus['위도'], errors='coerce')
gdf_seogu_bus['경도'] = pd.to_numeric(gdf_seogu_bus['경도'], errors='coerce')
gdf_seogu_bus = gdf_seogu_bus.dropna(subset=['위도', '경도'])

# 3. 정류장 데이터를 GeoDataFrame으로 변환
geometry = [Point(xy) for xy in zip(gdf_seogu_bus['경도'], gdf_seogu_bus['위도'])]
gdf_bus = gpd.GeoDataFrame(gdf_seogu_bus, geometry=geometry, crs='EPSG:4326')

# 4. 행정동 GeoJSON 불러오기
dong_geo_path = '/content/gdrive/My Drive/sw융합프로젝트(1)/인천광역시.geojson'
gdf_dong = gpd.read_file(dong_geo_path)
gdf_dong['sggnm'] = gdf_dong['sggnm'].str.strip()
gdf_dong = gdf_dong[gdf_dong['sggnm'] == '서구']

# 5. 공간 조인: 정류장이 포함된 행정동 찾기
gdf_joined = gpd.sjoin(gdf_bus, gdf_dong, how='inner', predicate='within')

# 6. 행정동별 정류장 수 집계
dong_counts = gdf_joined['adm_nm'].value_counts().reset_index()
dong_counts.columns = ['adm_nm', '정류장 수']

# 7. 병합
gdf_merge = gdf_dong.merge(dong_counts, on='adm_nm', how='left')
gdf_merge['정류장 수'] = gdf_merge['정류장 수'].fillna(0)

# 8. Choropleth 시각화
m = folium.Map(location=[37.545, 126.675], zoom_start=13)

folium.Choropleth(
    geo_data=gdf_merge.__geo_interface__,
    data=gdf_merge,
    columns=['adm_nm', '정류장 수'],
    key_on='feature.properties.adm_nm',
    fill_color='YlGnBu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='버스 정류장 수'
).add_to(m)

# 9. 툴팁 추가
folium.GeoJson(
    gdf_merge,
    name="행정동 경계",
    tooltip=folium.GeoJsonTooltip(
        fields=["adm_nm", "정류장 수"],
        aliases=["행정동", "정류장 수"],
        localize=True
    ),
    style_function=lambda x: {
        "fillOpacity": 0,
        "color": "gray",
        "weight": 1
    }
).add_to(m)

m.save('서구_정류장_자동추정_지도.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0962ec568a4abefb041fb552eca5785c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0962ec568a4abefb041fb552eca5785c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0962ec568a4abefb041fb552eca5785c = L.map(
#                 &quot;map_0962ec568a4abefb041fb552eca5785c&quot;,
#                 {
#                     center: [37.545, 126.675],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d800360012cc1c6eb4fe7d723cbe4039 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d800360012cc1c6eb4fe7d723cbe4039.addTo(map_0962ec568a4abefb041fb552eca5785c);
#
#
#             var choropleth_7a62833ad9a514c4225a15b5116a5e99 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_053be27ebd279a7862776f74e08963b3_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;13&quot;: case &quot;20&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#253494&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41b6c4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;6&quot;: case &quot;8&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;18&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c7e9b4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;15&quot;: case &quot;19&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2c7fb8&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7fcdbb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_053be27ebd279a7862776f74e08963b3_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_053be27ebd279a7862776f74e08963b3 = L.geoJson(null, {
#                 onEachFeature: geo_json_053be27ebd279a7862776f74e08963b3_onEachFeature,
#
#                 style: geo_json_053be27ebd279a7862776f74e08963b3_styler,
#             ...{
# }
#         });
#
#         function geo_json_053be27ebd279a7862776f74e08963b3_add (data) {
#             geo_json_053be27ebd279a7862776f74e08963b3
#                 .addData(data);
#         }
#             geo_json_053be27ebd279a7862776f74e08963b3_add({&quot;bbox&quot;: [126.55571481737333, 37.47334788579891, 126.72512592212895, 37.63957683199508], &quot;features&quot;: [{&quot;bbox&quot;: [126.55571481737333, 37.543833263707086, 126.70344213273648, 37.592707314660196], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[126.56832349585244, 37.57281742128982], [126.56842825375095, 37.57281371620233], [126.56866077274445, 37.5728384482149], [126.56880695830118, 37.57290744330951], [126.5692978800672, 37.573335390934155], [126.56934861972645, 37.573339899215426], [126.56974589095837, 37.57323197301826], [126.57110253396108, 37.572551100540764], [126.57115905891318, 37.57226848784268], [126.57105912329817, 37.572029364089836], [126.57001337189502, 37.57046666880928], [126.56923326368693, 37.570246318684845], [126.56415216793361, 37.57101721388526], [126.56157717160542, 37.57168326528929], [126.56144715387006, 37.5717333258857], [126.56120954416093, 37.57185037971426], [126.55865720859374, 37.57314954348513], [126.55571481737333, 37.57613734370768], [126.5

# %%
print(gdf_joined.head())
print(gdf_joined.crs, gdf_dong.crs)
print(gdf_merge[['adm_nm', '정류장 수']].sort_values('정류장 수', ascending=False).head())
# Out:
#         기준 일자      정류소 명   정류소 번호     정류소아이디  권역  행정동 명         엑스좌표  \
# 1  2024-12-31  (주)경동세라믹스  89146.0  168001146  서구  오류왕길동  166087.8384
# 2  2024-12-31   (주)경인양행앞  42096.0  168000096  서구   가좌1동  170343.6370
# 3  2024-12-31   (주)경인양행앞  42097.0  168000097  서구   석남2동  170465.3876
# 8  2024-12-31   (주)스킨이데아  89388.0  168001388  서구    원찬동  166105.6856
# 9  2024-12-31   (주)스킨이데아  89389.0  168001389  서구    원창동  166107.5171
#
#            경도         와이좌표         위도                    geometry  \
# 1  126.616978  450837.1724  37.559186  POINT (126.61698 37.55919)
# 2  126.665414  444145.8737  37.499045  POINT (126.66541 37.49905)
# 3  126.666789  444178.4131  37.499342  POINT (126.66679 37.49934)
# 8  126.617473  444479.2189  37.501903   POINT (126.61747 37.5019)
# 9  126.617495  444459.0933  37.501721   POINT (126.6175 37.50172)
#
#    index_right  OBJECTID          adm_nm   adm_cd     adm_cd2    sgg sido  \
# 1          109       873  인천광역시 서구 검암경서동  2308051  2826051500  28260   28
# 2          117       881   인천광역시 서구 가좌1동  2308062  2826058000  28260   28
# 3          115       879   인천광역시 서구 석남2동  2308059  2826056000  28260   28
# 8          124       888  인천광역시 서구 신현원창동  2308073  2826057500  28260   28
# 9          124       888  인천광역시 서구 신현원창동  2308073  2826057500  28260   28
#
#   sidonm sggnm
# 1  인천광역시    서구
# 2  인천광역시    서구
# 3  인천광역시    서구
# 8  인천광역시    서구
# 9  인천광역시    서구
# EPSG:4326 EPSG:4326
#             adm_nm  정류장 수
# 20   인천광역시 서구 청라3동    118
# 0   인천광역시 서구 검암경서동    111
# 13    인천광역시 서구 원당동    109
# 15  인천광역시 서구 신현원창동     88
# 19  인천광역시 서구 오류왕길동     84
